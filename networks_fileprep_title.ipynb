# %% [markdown]
# ### Headline network for left and right news media
#
# <span style="font-family: 'Verdana', sans-serif; font-size: 16px;line-height: 1.5;">
# This script processes the news article titles, initially cleaning and splitting the data into subsets based on left and right political ideologies. It then tokenizes the titles, identifies co-occurrences of words in each subset, and filters these co-occurrences based on frequency. The resulting information is organized into DataFrames representing edges between words, with additional attributes such as weights. The script also incorporates word counts and Shifterator scores, linking these values to the corresponding nodes. The final output includes filtered DataFrames for edges and nodes, providing insights into the relationships and frequencies of words within the context of left and right ideologies in news media titles.<span>

# %%
# Importing modules
import pandas as pd
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from itertools import combinations
from collections import defaultdict
import operator

# %%
# load categorised data by media ideological affiliation
df = pd.read_csv('C:/Users/2146806A/OneDrive - University of Glasgow/University of Glasgow/Amsterdam Visit/GITHUB FILES/Data/preprocessed_nov23.csv', encoding='latin-1')
nodes_df = pd.read_csv('C:/Users/2146806A/OneDrive - University of Glasgow/University of Glasgow/Amsterdam Visit/GITHUB FILES/Data/shifterator_scores_text_nov23.csv', encoding='latin-1')
df.head()
# Out:
#          date                                           maintext  \
# 0  03/01/2013  greg gutfeld co host hello america greg gutfel...
# 1  11/01/2013  late threat leadership easily speaker house jo...
# 2  18/01/2013  story highlight mill remember march selma mont...
# 3  20/01/2013  barack michelle obama spend thousand day displ...
# 4  21/01/2013  sean_hannity host hannity moment ago president...
#
#                                        title  \
# 0  reagan era over al jazeera buy current tv
# 1              job safe straus challenge gop
# 2    year mlk march voting rights vulnerable
# 3        change come year friend shift obama
# 4                                  karl rove
#
#                                               source          media_name  \
# 0  C:/Users/2146806A/OneDrive - University of Gla...            Fox News
# 1  C:/Users/2146806A/OneDrive - University of Gla...  The New York Times
# 2  https://edition.cnn.com/2013/01/18/opinion/mil...                 CNN
# 3  C:/Users/2146806A/OneDrive - University of Gla...  The New York Times
# 4  C:/Users/2146806A/OneDrive - University of Gla...            Fox News
#
#   ideology Congress                                  maintext_fullstop
# 0    right    113th  greg gutfeld co host hello america . greg gutf...
# 1     left    113th  late threat leadership easily speaker house jo...
# 2     left    113th  story highlight mill remember march selma mont...
# 3     left    113th  barack michelle obama spend thousand day displ...
# 4    right    113th  sean_hannity host hannity moment ago president...

# %% [markdown]
# ## Co-occurrences in headlines

# %%
df['title'] = df['title'].str.replace("'", "")

# %%
# Split corpus into right and left news media
left = df[df['ideology'].isin(['left'])]
right = df[df['ideology'].isin(['right'])]

# we want to find co-occurrences of words in headlines so we convert the title column into a list
right_list = right['title'].tolist()
left_list = left['title'].tolist()

# %%
tokenized_left = [word_tokenize(item) for item in left['title'] if isinstance(item, str) and item.strip()]
tokenized_right = [word_tokenize(item) for item in right['title'] if isinstance(item, str) and item.strip()]

# %% [markdown]
# We then create an edge list dictionary. For every word that occurs with another word we give it a value of 1. <br>
# So it looks like this: <br>
#  {('ways', 'league'): 2, <br>
#    ('ways', 'women'): 2, <br>
#   ('ways', 'voters'): 3, ... <br>

# %%
# edgelist dictionary for right
edgelist_right = defaultdict(int)
for text in tokenized_right:
    for node1, node2 in combinations(text, 2):
        if node1 != node2:  # Skip pairs with the same node
            edgelist_right[(node1, node2)] += 1

# left
edgelist_left = defaultdict(int)
for text in tokenized_left:
    for node1, node2 in combinations(text, 2):
        if node1 != node2:  # Skip pairs with the same node
            edgelist_left[(node1, node2)] += 1

# %%
# RIGHT
sorted_edges_r = sorted(edgelist_right.items(), key=operator.itemgetter(1), reverse = True)
sorted_edges_r

# LEFT
sorted_edges_l = sorted(edgelist_left.items(), key=operator.itemgetter(1), reverse = True)
sorted_edges_l
# Out:
# [(('voter', 'identification'), 235),
#  (('identification', 'law'), 111),
#  (('voter', 'law'), 103),
#  (('biden', 'coronavirus'), 88),
#  (('democrats', 'biden'), 85),
#  (('biden', 'border'), 82),
#  (('coronavirus', 'biden'), 73),
#  (('biden', 'united_states'), 70),
#  (('election', 'law'), 66),
#  (('democrats', 'election'), 66),
#  (('biden', 'administration'), 65),
#  (('trump', 'biden'), 61),
#  (('democrats', 'bill'), 61),
#  (('biden', 'democrats'), 61),
#  (('georgia', 'law'), 60),
#  (('biden', 'republican'), 60),
#  (('democrats', 'republican'), 56),
#  (('biden', 'crisis'), 56),
#  (('voting', 'law'), 55),
#  (('election', 'integrity'), 53),
#  (('election', 'bill'), 52),
#  (('voting', 'bill'), 51),
#  (('democrats', 'coronavirus'), 50),
#  (('biden', 'people'), 50),
#  (('trump', 'election'), 48),
#  (('biden', 'media'), 46),
#  (('gop', 'biden'), 46),
#  (('trump', 'united_states'), 45),
#  (('election', 'biden'), 45),
#  (('democrats', 'voting'), 44),
#  (('republican', 'biden'), 44),
#  (('biden', 'election'), 43),
#  (('biden', 'state'), 43),
#  (('biden', 'trump'), 42),
#  (('biden', 'bill'), 42),
#  (('trump', 'voter'), 40),
#  (('biden', 'senator'), 40),
#  (('border', 'biden'), 39),
#  (('biden', 'governor'), 39),
#  (('voter', 'fraud'), 38),
#  (('biden', 'china'), 38),
#  (('biden', 'voting'), 38),
#  (('biden', 'vaccine'), 38),
#  (('biden', 'push'), 37),
#  (('georgia', 'voting'), 37),
#  (('coronavirus', 'united_states'), 36),
#  (('biden', 'mandate'), 36),
#  (('united_states', 'biden'), 35),
#  (('mail', 'in'), 35),
#  (('media', 'biden'), 35),
#  (('governor', 'biden'), 35),
#  (('china', 'biden'), 34),
#  (('voting', 'rights'), 33),
#  (('biden', 'new_york'), 33),
#  (('biden', 'policy'), 32),
#  (('biden', 'law'), 32),
#  (('biden', 'georgia'), 32),
#  (('texas', 'voter'), 31),
#  (('democrats', 'law'), 31),
#  (('election', 'voter'), 31),
#  (('voter', 'election'), 31),
#  (('republican', 'trump'), 31),
#  (('trump', 'republican'), 30),
#  (('border', 'crisis'), 30),
#  (('biden', 'congress'), 30),
#  (('democrats', 'vote'), 29),
#  (('trump', 'vote'), 29),
#  (('democrats', 'gop'), 29),
#  (('biden', 'health'), 29),
#  (('biden', 'discuss'), 29),
#  (('biden', 'president'), 29),
#  (('america', 'biden'), 29),
#  (('biden', 'address'), 29),
#  (('democrats', 'voter'), 28),
#  (('gop', 'election'), 28),
#  (('state', 'biden'), 28),
#  (('biden', 'call'), 28),
#  (('biden', 'fauci'), 28),
#  (('georgia', 'election'), 28),
#  (('governor', 'ron_desantis'), 28),
#  (('texas', 'identification'), 27),
#  (('all', 'star'), 27),
#  (('media', 'trump'), 27),
#  (('push', 'coronavirus'), 27),
#  (('governor', 'florida'), 27),
#  (('biden', 'gop'), 27),
#  (('mlb', 'star'), 27),
#  (('election', 'reform'), 26),
#  (('republican', 'gop'), 26),
#  (('mail', 'ballot'), 26),
#  (('democrats', 'push'), 26),
#  (('republican', 'election'), 26),
#  (('biden', 'senate'), 26),
#  (('voting', 'biden'), 26),
#  (('biden', 'criticize'), 26),
#  (('mlb', 'game'), 26),
#  (('star', 'game'), 26),
#  (('voter', 'suppression'), 25),
#  (('democrat', 'election'), 25),
#  (('biden', 'speech'), 25),
#  (('trump', 'campaign'), 25),
#  (('biden', 'vote'), 25),
#  (('bill', 'biden'), 25),
#  (('senator', 'south_carolina'), 25),
#  (('voting', 'coronavirus'), 25),
#  (('biden', 'child'), 25),
#  (('biden', 'admin'), 25),
#  (('biden', 'florida'), 25),
#  (('mlb', 'all'), 25),
#  (('mandate', 'biden'), 25),
#  (('biden', 'man'), 25),
#  (('election', 'state'), 24),
#  (('gop', 'trump'), 24),
#  (('democrats', 'border'), 24),
#  (('democrats', 'media'), 24),
#  (('voter', 'biden'), 24),
#  (('bill', 'coronavirus'), 24),
#  (('biden', 'press_conference'), 24),
#  (('senator', 'lindsey_graham'), 24),
#  (('georgia', 'biden'), 24),
#  (('biden', 'migrant'), 24),
#  (('biden', 'issue'), 24),
#  (('all', 'game'), 24),
#  (('biden', 'infrastructure'), 24),
#  (('texas', 'law'), 23),
#  (('trump', 'border'), 23),
#  (('republican', 'voter'), 23),
#  (('democrats', 'trump'), 23),
#  (('governor', 'republican'), 23),
#  (('coronavirus', 'trump'), 23),
#  (('coronavirus', 'vaccine'), 23),
#  (('georgia', 'coronavirus'), 23),
#  (('biden', 'plan'), 23),
#  (('florida', 'governor'), 23),
#  (('trump', 'white_house'), 22),
#  (('democrats', 'senator'), 22),
#  (('biden', 'attack'), 22),
#  (('coronavirus', 'people'), 22),
#  (('vote', 'mail'), 22),
#  (('biden', 'white_house'), 22),
#  (('crisis', 'biden'), 22),
#  (('administration', 'biden'), 22),
#  (('democracy', 'biden'), 22),
#  (('voter', 'gop'), 21),
#  (('gop', 'voter'), 21),
#  (('trump', 'russia'), 21),
#  (('vote', 'election'), 21),
#  (('united_states', 'trump'), 21),
#  (('bill', 'trump'), 21),
#  (('coronavirus', 'pandemic'), 21),
#  (('coronavirus', 'push'), 21),
#  (('democrats', 'state'), 21),
#  (('biden', 'year'), 21),
#  (('democrat', 'biden'), 21),
#  (('republican', 'coronavirus'), 21),
#  (('texas', 'biden'), 21),
#  (('policy', 'biden'), 21),
#  (('vaccine', 'biden'), 21),
#  (('texas', 'democrats'), 21),
#  (('identification', 'requirement'), 20),
#  (('trump', 'rally'), 20),
#  (('democrats', 'united_states'), 20),
#  (('florida', 'ron_desantis'), 20),
#  (('biden', 'california'), 20),
#  (('election', 'trump'), 20),
#  (('coronavirus', 'business'), 20),
#  (('media', 'democrats'), 20),
#  (('democrats', 'governor'), 20),
#  (('biden', 'americans'), 20),
#  (('americans', 'biden'), 20),
#  (('biden', 'kamala_kamala_kamala_harris'), 20),
#  (('biden', 'texas'), 20),
#  (('biden', 'lie'), 20),
#  (('biden', 'meet'), 20),
#  (('law', 'biden'), 20),
#  (('biden', 'filibuster'), 20),
#  (('ron_desantis', 'florida'), 20),
#  (('biden', 'university'), 20),
#  (('state', 'election'), 19),
#  (('democrats', 'plan'), 19),
#  (('republican', 'voting'), 19),
#  (('border', 'trump'), 19),
#  (('trump', 'state'), 19),
#  (('election', 'vote'), 19),
#  (('mail', 'vote'), 19),
#  (('biden', 'america'), 19),
#  (('biden', 'gun'), 19),
#  (('coronavirus', 'media'), 19),
#  (('one', 'biden'), 19),
#  (('united_states', 'coronavirus'), 19),
#  (('biden', 'hold'), 19),
#  (('biden', 'kamala_kamala_kamala_kamala_harris'), 19),
#  (('democrats', 'make'), 19),
#  (('coronavirus', 'republican'), 19),
#  (('republican', 'new_york'), 19),
#  (('biden', 'agenda'), 19),
#  (('biden', 'country'), 19),
#  (('biden', 'crime'), 19),
#  (('russia', 'ukraine'), 18),
#  (('republican', 'senator'), 18),
#  (('early', 'voting'), 18),
#  (('gop', 'republican'), 18),
#  (('vote', 'law'), 18),
#  (('trump', 'identification'), 18),
#  (('in', 'vote'), 18),
#  (('trump', 'media'), 18),
#  (('georgia', 'voter'), 18),
#  (('election', 'republican'), 18),
#  (('democrats', 'party'), 18),
#  (('push', 'biden'), 18),
#  (('coronavirus', 'new_york'), 18),
#  (('coronavirus', 'discuss'), 18),
#  (('america', 'coronavirus'), 18),
#  (('coronavirus', 'fauci'), 18),
#  (('biden', 'back'), 18),
#  (('biden', 'city'), 18),
#  (('senator', 'biden'), 18),
#  (('hold', 'biden'), 18),
#  (('election', 'coronavirus'), 18),
#  (('question', 'biden'), 18),
#  (('biden', 'claim'), 18),
#  (('biden', 'democrat'), 18),
#  (('coronavirus', 'border'), 18),
#  (('biden', 'kid'), 18),
#  (('biden', 'mask'), 18),
#  (('texas', 'bill'), 18),
#  (('biden', 'dr'), 18),
#  (('biden', 'rights'), 18),
#  (('florida', 'discuss'), 18),
#  (('presidential', 'election'), 17),
#  (('election', 'identification'), 17),
#  (('election', 'democrats'), 17),
#  (('court', 'voter'), 17),
#  (('court', 'identification'), 17),
#  (('republican', 'state'), 17),
#  (('trump', 'gop'), 17),
#  (('gop', 'democrats'), 17),
#  (('democrats', 'claim'), 17),
#  (('illegal', 'immigrant'), 17),
#  (('governor', 'bill'), 17),
#  (('white_house', 'biden'), 17),
#  (('migrant', 'biden'), 17),
#  (('power', 'grab'), 17),
#  (('republican', 'bill'), 17),
#  (('biden', 'illegal'), 17),
#  (('america', 'republican'), 17),
#  (('trump', 'coronavirus'), 17),
#  (('party', 'biden'), 17),
#  (('coronavirus', 'bill'), 17),
#  (('new_york', 'biden'), 17),
#  (('state', 'coronavirus'), 17),
#  (('republican', 'governor'), 17),
#  (('republican', 'democrats'), 17),
#  (('biden', 'russia'), 17),
#  (('florida', 'coronavirus'), 17),
#  (('coronavirus', 'administration'), 17),
#  (('lindsey_graham', 'south_carolina'), 17),
#  (('biden', 'case'), 17),
#  (('biden', 'parent'), 17),
#  (('georgia', 'bill'), 17),
#  (('biden', 'police'), 17),
#  (('biden', 'school'), 17),
#  (('biden', 'pass'), 17),
#  (('border', 'united_states'), 17),
#  (('democrats', 'dr'), 17),
#  (('biden', 'protest'), 17),
#  (('biden', 'inflation'), 17),
#  (('governor', 'discuss'), 17),
#  (('gop', 'vote'), 16),
#  (('crisis', 'republican'), 16),
#  (('photo', 'identification'), 16),
#  (('united_states', 'election'), 16),
#  (('state', 'voter'), 16),
#  (('bill', 'voter'), 16),
#  (('north_carolina', 'voter'), 16),
#  (('north_carolina', 'identification'), 16),
#  (('real', 'identification'), 16),
#  (('republican', 'people'), 16),
#  (('state', 'law'), 16),
#  (('secretary', 'state'), 16),
#  (('trump', 'senate'), 16),
#  (('senate', 'trump'), 16),
#  (('senator', 'republican'), 16),
#  (('comey', 'trump'), 16),
#  (('election', 'result'), 16),
#  (('trump', 'greg'), 16),
#  (('trump', 'health'), 16),
#  (('gop', 'voting'), 16),
#  (('senate', 'biden'), 16),
#  (('plan', 'biden'), 16),
#  (('biden', 'run'), 16),
#  (('democrats', 'white_house'), 16),
#  (('democrats', 'people'), 16),
#  (('democrats', 'america'), 16),
#  (('border', 'republican'), 16),
#  (('coronavirus', 'state'), 16),
#  (('coronavirus', 'spread'), 16),
#  (('coronavirus', 'hydroxychloroquine'), 16),
#  (('coronavirus', 'press_conference'), 16),
#  (('democratic', 'biden'), 16),
#  (('coronavirus', 'dr'), 16),
#  (('biden', 'report'), 16),
#  (('in', 'ballot'), 16),
#  (('americans', 'day'), 16),
#  (('end', 'biden'), 16),
#  (('georgia', 'state'), 16),
#  (('florida', 'biden'), 16),
#  (('china', 'coronavirus'), 16),
#  (('trump', 'georgia'), 16),
#  (('biden', 'project'), 16),
#  (('biden', 'secretary'), 16),
#  (('texas', 'governor'), 16),
#  (('governor', 'coronavirus'), 16),
#  (('biden', 'cdc'), 16),
#  (('biden', 'student'), 16),
#  (('china', 'united_states'), 16),
#  (('vaccine', 'passport'), 16),
#  (('integrity', 'law'), 16),
#  (('biden', 'ron_desantis'), 16),
#  (('biden', 'anthony'), 16),
#  (('biden', 'booster'), 16),
#  (('republican', 'house'), 15),
#  (('senator', 'bill'), 15),
#  (('republican', 'united_states'), 15),
#  (('voter', 'democrats'), 15),
#  (('judge', 'identification'), 15),
#  (('voter', 'bill'), 15),
#  (('trump', 'people'), 15),
#  (('trump', 'president'), 15),
#  (('trump', 'justice'), 15),
#  (('voter', 'trump'), 15),
#  (('trump', 'presidential'), 15),
#  (('vote', 'trump'), 15),
#  (('election', 'fraud'), 15),
#  (('trump', 'news'), 15),
#  (('bill', 'identification'), 15),
#  (('bill', 'law'), 15),
#  (('agenda', 'biden'), 15),
#  (('united_states', 'bill'), 15),
#  (('trump', 'democrats'), 15),
#  (('leader', 'gop'), 15),
#  (('florida', 'law'), 15),
#  (('report', 'biden'), 15),
#  (('united_states', 'border'), 15),
#  (('border', 'democrats'), 15),
#  (('biden', 'justice'), 15),
#  (('biden', 'voter'), 15),
#  (('border', 'bill'), 15),
#  (('democrats', 'reform'), 15),
#  (('republican', 'democrat'), 15),
#  (('election', 'voting'), 15),
#  (('voting', 'reform'), 15),
#  (('bill', 'united_states'), 15),
#  (('lockdown', 'coronavirus'), 15),
#  (('trillion', 'coronavirus'), 15),
#  (('democratic', 'coronavirus'), 15),
#  (('vote', 'by'), 15),
#  (('dr', 'fauci'), 15),
#  (('governor', 'election'), 15),
#  (('coronavirus', 'senator'), 15),
#  (('hunter', 'biden'), 15),
#  (('business', 'biden'), 15),
#  (('senate', 'election'), 15),
#  (('state', 'voting'), 15),
#  (('republican', 'jim'), 15),
#  (('republican', 'fl'), 15),
#  (('biden', 'supreme_court'), 15),
#  (('gop', 'china'), 15),
#  (('biden', 'legislation'), 15),
#  (('biden', 'post'), 15),
#  (('biden', 'harry'), 15),
#  (('police', 'biden'), 15),
#  (('coronavirus', 'florida'), 15),
#  (('coronavirus', 'law'), 15),
#  (('mlb', 'georgia'), 15),
#  (('biden', 'billion'), 15),
#  (('biden', 'vaccinate'), 15),
#  (('republican', 'vote'), 14),
#  (('united_states', 'state'), 14),
#  (('state', 'united_states'), 14),
#  (('democrats', 'race'), 14),
#  (('gop', 'law'), 14),
#  (('voter', 'vote'), 14),
#  (('biden', 'liberal'), 14),
#  (('voter', 'requirement'), 14),
#  (('gop', 'win'), 14),
#  (('appeal', 'court'), 14),
#  (('gop', 'state'), 14),
#  (('trump', 'security'), 14),
#  (('senate', 'race'), 14),
#  (('democrat', 'voter'), 14),
#  (('trump', 'fraud'), 14),
#  (('election', 'mail'), 14),
#  (('bill', 'voting'), 14),
#  (('trump', 'house'), 14),
#  (('wake', 'biden'), 14),
#  (('rally', 'trump'), 14),
#  (('russia', 'united_states'), 14),
#  (('america', 'trump'), 14),
#  (('america', 'democrats'), 14),
#  (('georgia', 'race'), 14),
#  (('trump', 'life'), 14),
#  (('gop', 'bill'), 14),
#  (('state', 'governor'), 14),
#  (('democrats', 'power'), 14),
#  (('biden', 'anti'), 14),
#  (('democrat', 'gop'), 14),
#  (('voting', 'united_states'), 14),
#  (('trump', 'administration'), 14),
#  (('biden', 'company'), 14),
#  (('biden', 'democratic'), 14),
#  (('spread', 'coronavirus'), 14),
#  (('hydroxychloroquine', 'coronavirus'), 14),
#  (('media', 'coronavirus'), 14),
#  (('by', 'mail'), 14),
#  (('coronavirus', 'crisis'), 14),
#  (('democrats', 'new_york'), 14),
#  (('biden', 'ahead'), 14),
#  (('biden', 'warn'), 14),
#  (('coronavirus', 'case'), 14),
#  (('fauci', 'coronavirus'), 14),
#  (('democrats', 'senate'), 14),
#  (('white_house', 'press_secretary'), 14),
#  (('administration', 'coronavirus'), 14),
#  (('biden', 'question'), 14),
#  (('biden', 'street'), 14),
#  (('biden', 'test'), 14),
#  (('democrats', 'american'), 14),
#  (('georgia', 'united_states'), 14),
#  (('biden', 'move'), 14),
#  (('coronavirus', 'georgia'), 14),
#  (('support', 'identification'), 14),
#  (('biden', 'control'), 14),
#  (('control', 'biden'), 14),
#  (('gop', 'president'), 14),
#  (('biden', 'rating'), 14),
#  (('biden', 'political'), 14),
#  (('biden', 'show'), 14),
#  (('democrats', 'texas'), 14),
#  (('biden', 'leader'), 14),
#  (('biden', 'arrest'), 14),
#  (('republican', 'tx'), 14),
#  (('coronavirus', 'mandate'), 14),
#  (('biden', 'vax'), 14),
#  (('midterm', 'biden'), 14),
#  (('ron_desantis', 'discuss'), 14),
#  (('republican', 'party'), 13),
#  (('midterm', 'election'), 13),
#  (('election', 'united_states'), 13),
#  (('voter', 'registration'), 13),
#  (('gop', 'back'), 13),
#  (('judge', 'voter'), 13),
#  (('win', 'election'), 13),
#  (('house', 'bill'), 13),
#  (('appeal', 'identification'), 13),
#  (('trump', 'criticize'), 13),
#  (('black', 'voter'), 13),
#  (('russia', 'trump'), 13),
#  (('florida', 'trump'), 13),
#  (('trump', 'probe'), 13),
#  (('trump', 'pass'), 13),
#  (('russia', 'biden'), 13),
#  (('anti', 'biden'), 13),
#  (('house', 'trump'), 13),
#  (('democrats', 'woman'), 13),
#  (('gop', 'united_states'), 13),
#  (('push', 'vote'), 13),
#  (('republican', 'georgia'), 13),
#  (('biden', 'comment'), 13),
#  (('claim', 'biden'), 13),
#  (('coronavirus', 'hold'), 13),
#  (('test', 'coronavirus'), 13),
#  (('patient', 'coronavirus'), 13),
#  (('lie', 'coronavirus'), 13),
#  (('biden', 'business'), 13),
#  (('coronavirus', 'plan'), 13),
#  (('face', 'biden'), 13),
#  (('biden', 'campaign'), 13),
#  (('coronavirus', 'election'), 13),
#  (('biden', 'slam'), 13),
#  (('democrats', 'crisis'), 13),
#  (('back', 'biden'), 13),
#  (('media', 'republican'), 13),
#  (('make', 'biden'), 13),
#  (('biden', 'surge'), 13),
#  (('push', 'election'), 13),
#  (('gop', 'question'), 13),
#  (('race', 'biden'), 13),
#  (('year', 'biden'), 13),
#  (('biden', 'stop'), 13),
#  (('senator', 'la'), 13),
#  (('leader', 'biden'), 13),
#  (('biden', 'expert'), 13),
#  (('supreme_court', 'biden'), 13),
#  (('georgia', 'dr'), 13),
#  (('biden', 'cartel'), 13),
#  (('biden', 'failure'), 13),
#  (('democrats', 'cdc'), 13),
#  (('coronavirus', 'call'), 13),
#  (('biden', 'open'), 13),
#  (('address', 'biden'), 13),
#  (('shoot', 'biden'), 13),
#  (('biden', 'news'), 13),
#  (('hold', 'day'), 13),
#  (('biden', 'reform'), 13),
#  (('biden', 'talk'), 13),
#  (('democrats', 'police'), 13),
#  (('democrats', 'mask'), 13),
#  (('coronavirus', 'police'), 13),
#  (('biden', 'culture'), 13),
#  (('biden', 'make'), 13),
#  (('americans', 'enemy'), 13),
#  (('rights', 'florida'), 13),
#  (('law', 'election'), 12),
#  (('democrats', 'attack'), 12),
#  (('republican', 'question'), 12),
#  (('identification', 'election'), 12),
#  (('policy', 'republican'), 12),
#  (('senator', 'democrats'), 12),
#  (('election', 'gop'), 12),
#  (('attorney', 'general'), 12),
#  (('back', 'identification'), 12),
#  (('federal', 'law'), 12),
#  (('election', 'day'), 12),
#  (('identification', 'bill'), 12),
#  (('lawmaker', 'identification'), 12),
#  (('trump', 'new_york'), 12),
#  (('trump', 'wall'), 12),
#  (('governor', 'law'), 12),
#  (('trump', 'issue'), 12),
#  (('people', 'united_states'), 12),
#  (('push', 'united_states'), 12),
#  (('appeal', 'voter'), 12),
#  (('trump', 'report'), 12),
#  (('report', 'trump'), 12),
#  (('trump', 'effort'), 12),
#  (('percent', 'voter'), 12),
#  (('law', 'united_states'), 12),
#  (('trump', 'candidate'), 12),
#  (('pass', 'bill'), 12),
#  (('house', 'biden'), 12),
#  (('governor', 'immigrant'), 12),
#  (('house', 'democrats'), 12),
#  (('gop', 'plan'), 12),
#  (('trump', 'bill'), 12),
#  (('trump', 'call'), 12),
#  (('require', 'identification'), 12),
#  (('georgia', 'republican'), 12),
#  (('gop', 'governor'), 12),
#  (('trump', 'criminal'), 12),
#  (('country', 'biden'), 12),
#  (('state', 'democrats'), 12),
#  (('democrats', 'president'), 12),
#  (('southern', 'border'), 12),
#  (('border', 'senator'), 12),
#  (('republican', 'florida'), 12),
#  (('republican', 'administration'), 12),
#  (('campaign', 'biden'), 12),
#  (('trump', 'democratic'), 12),
#  (('democrats', 'democratic'), 12),
#  (('coronavirus', 'show'), 12),
#  (('coronavirus', 'due'), 12),
#  (('campaign', 'coronavirus'), 12),
#  (('expose', 'coronavirus'), 12),
#  (('biden', 'due'), 12),
#  (('coronavirus', 'president'), 12),
#  (('americans', 'coronavirus'), 12),
#  (('anthony', 'fauci'), 12),
#  (('protest', 'biden'), 12),
#  (('coronavirus', 'democrats'), 12),
#  (('year', 'coronavirus'), 12),
#  (('law', 'coronavirus'), 12),
#  (('bill', 'election'), 12),
#  (('biden', 'amid'), 12),
#  (('liberal', 'democrats'), 12),
#  (('surge', 'biden'), 12),
#  (('million', 'biden'), 12),
#  (('election', 'georgia'), 12),
#  (('republican', 'jordan'), 12),
#  (('republican', 'oh'), 12),
#  (('case', 'biden'), 12),
#  (('georgia', 'white_house'), 12),
#  (('team', 'biden'), 12),
#  (('china', 'state'), 12),
#  (('biden', 'respond'), 12),
#  (('gop', 'criticize'), 12),
#  (('democrats', 'georgia'), 12),
#  (('integrity', 'bill'), 12),
#  (('biden', 'blame'), 12),
#  (('admin', 'biden'), 12),
#  (('georgia', 'democrats'), 12),
#  (('voting', 'democrats'), 12),
#  (('biden', 'compare'), 12),
#  (('biden', 'shoot'), 12),
#  (('coronavirus', 'child'), 12),
#  (('support', 'voter'), 12),
#  (('biden', 'south_carolina'), 12),
#  (('border', 'people'), 12),
#  (('biden', 'day'), 12),
#  (('biden', 'block'), 12),
#  (('administration', 'united_states'), 12),
#  (('day', 'biden'), 12),
#  (('democrats', 'vaccine'), 12),
#  (('democrats', 'fauci'), 12),
#  (('dr', 'coronavirus'), 12),
#  (('biden', 'star'), 12),
#  (('mlb', 'atlanta'), 12),
#  (('democrats', 'back'), 12),
#  (('democrats', 'mandate'), 12),
#  (('biden', 'capitol'), 12),
#  (('gop', 'administration'), 12),
#  (('vax', 'mandate'), 12),
#  (('americans', 'hold'), 12),
#  (('biden', 'majority'), 12),
#  (('discuss', 'florida'), 12),
#  (('gop', 'answer'), 12),
#  (('back', 'voter'), 11),
#  (('senate', 'democrats'), 11),
#  (('law', 'state'), 11),
#  (('federal', 'election'), 11),
#  (('senator', 'cruz'), 11),
#  (('ted', 'cruz'), 11),
#  (('democrats', 'black'), 11),
#  (('house', 'vote'), 11),
#  (('state', 'bill'), 11),
#  (('federal', 'identification'), 11),
#  (('court', 'law'), 11),
#  (('biden', 'race'), 11),
#  (('governor', 'trump'), 11),
#  (('law', 'governor'), 11),
#  (('united_states', 'voter'), 11),
#  (('united_states', 'identification'), 11),
#  (('identification', 'vote'), 11),
#  (('north_carolina', 'law'), 11),
#  (('trump', 'attack'), 11),
#  (('vp', 'trump'), 11),
#  (('judge', 'texas'), 11),
#  (('voting', 'gop'), 11),
#  (('win', 'trump'), 11),
#  (('border', 'voting'), 11),
#  (('trump', 'lead'), 11),
#  (('big', 'biden'), 11),
#  (('state', 'trump'), 11),
#  (('voter', 'people'), 11),
#  (('ohio', 'trump'), 11),
#  (('united_states', 'white_house'), 11),
#  (('texas', 'voting'), 11),
#  (('trump', 'illegal'), 11),
#  (('sign', 'law'), 11),
#  (('gop', 'leader'), 11),
#  (('trump', 'run'), 11),
#  (('threat', 'biden'), 11),
#  (('trump', 'make'), 11),
#  (('democrat', 'trump'), 11),
#  (('democrat', 'bill'), 11),
#  (('michael', 'trump'), 11),
#  (('push', 'back'), 11),
#  (('governor', 'race'), 11),
#  (('call', 'united_states'), 11),
#  (('gop', 'democrat'), 11),
#  (('trump', 'continue'), 11),
#  (('lie', 'biden'), 11),
#  (('biden', 'lose'), 11),
#  (('republican', 'media'), 11),
#  (('democrat', 'republican'), 11),
#  (('voting', 'call'), 11),
#  (('charge', 'trump'), 11),
#  (('biden', 'immigration'), 11),
#  (('governor', 'gop'), 11),
#  (('trump', 'million'), 11),
#  (('trump', 'senator'), 11),
#  (('bill', 'people'), 11),
#  (('biden', 'continue'), 11),
#  (('coronavirus', 'governor'), 11),
#  (('america', 'state'), 11),
#  (('biden', 'party'), 11),
#  (('national', 'coronavirus'), 11),
#  (('coronavirus', 'patient'), 11),
#  (('coronavirus', 'lie'), 11),
#  (('coronavirus', 'shutdown'), 11),
#  (('general', 'coronavirus'), 11),
#  (('show', 'coronavirus'), 11),
#  (('democrats', 'mail'), 11),
#  (('americans', 'democrats'), 11),
#  (('biden', 'executive'), 11),
#  (('biden', 'team'), 11),
#  (('biden', 'vice'), 11),
#  (('coronavirus', 'white_house'), 11),
#  (('vice', 'president'), 11),
#  (('media', 'election'), 11),
#  (('democrats', 'americans'), 11),
#  (('vote', 'biden'), 11),
#  (('biden', 'hunter'), 11),
#  (('biden', 'presidency'), 11),
#  (('china', 'election'), 11),
#  (('presidency', 'biden'), 11),
#  (('democrats', 'candidate'), 11),
#  (('senate', 'vote'), 11),
#  (('biden', 'presidential'), 11),
#  (('election', 'white_house'), 11),
#  (('white_house', 'kayleigh'), 11),
#  (('white_house', 'mcenany'), 11),
#  (('press_secretary', 'kayleigh'), 11),
#  (('press_secretary', 'mcenany'), 11),
#  (('kayleigh', 'mcenany'), 11),
#  (('jim', 'jordan'), 11),
#  (('jim', 'oh'), 11),
#  (('jordan', 'oh'), 11),
#  (('biden', 'take'), 11),
#  (('voter', 'republican'), 11),
#  (('senator', 'john_kennedy'), 11),
#  (('plan', 'trump'), 11),
#  (('biden', 'progressive'), 11),
#  (('democrats', 'policy'), 11),
#  (('end', 'coronavirus'), 11),
#  (('january', 'th'), 11),
#  (('biden', 'refuse'), 11),
#  (('bill', 'republican'), 11),
#  (('people', 'biden'), 11),
#  (('media', 'bill'), 11),
#  (('voting', 'white_house'), 11),
#  (('reform', 'coronavirus'), 11),
#  (('coronavirus', 'trial'), 11),
#  (('cdc', 'coronavirus'), 11),
#  (('biden', 'washington'), 11),
#  (('biden', 'lindsey_graham'), 11),
#  (('biden', 'fail'), 11),
#  (('biden', 'southern'), 11),
#  (('child', 'biden'), 11),
#  (('biden', 'put'), 11),
#  (('gop', 'student'), 11),
#  (('united_states', 'china'), 11),
#  (('kamala_kamala_kamala_harris', 'border'), 11),
#  (('georgia', 'people'), 11),
#  (('republican', 'border'), 11),
#  (('show', 'democrats'), 11),
#  (('policy', 'coronavirus'), 11),
#  (('coronavirus', 'china'), 11),
#  (('voting', 'dr'), 11),
#  (('biden', 'cancel'), 11),
#  (('biden', 'wear'), 11),
#  (('ron_desantis', 'biden'), 11),
#  (('biden', 'low'), 11),
#  (('radical', 'biden'), 11),
#  (('democrats', 'support'), 11),
#  (('democrat', 'coronavirus'), 11),
#  (('russia', 'china'), 11),
#  (('democrats', 'hunter'), 11),
#  (('biden', 'host'), 11),
#  (('biden', 'work'), 11),
#  (('rights', 'biden'), 11),
#  (('americans', 'hostage'), 11),
#  (('americans', 'line'), 11),
#  (('hold', 'hostage'), 11),
#  (('hold', 'enemy'), 11),
#  (('hold', 'line'), 11),
#  (('hostage', 'enemy'), 11),
#  (('hostage', 'line'), 11),
#  (('hostage', 'day'), 11),
#  (('enemy', 'line'), 11),
#  (('enemy', 'day'), 11),
#  (('line', 'day'), 11),
#  (('democrats', 'midterm'), 11),
#  (('gop', 'university'), 11),
#  (('supreme_court', 'voter'), 10),
#  (('democrats', 'identification'), 10),
#  (('tim', 'scott'), 10),
#  (('democrats', 'question'), 10),
#  (('senator', 'ted'), 10),
#  (('fraud', 'election'), 10),
#  (('america', 'election'), 10),
#  (('democrat', 'vote'), 10),
#  (('claim', 'law'), 10),
#  (('republican', 'call'), 10),
#  (('call', 'voting'), 10),
#  (('liberal', 'media'), 10),
#  (('vote', 'identification'), 10),
#  (('house', 'voter'), 10),
#  (('new_york', 'trump'), 10),
#  (('governor', 'united_states'), 10),
#  (('trump', 'face'), 10),
#  (('trump', 'governor'), 10),
#  (('lawmaker', 'voter'), 10),
#  (('state', 'identification'), 10),
#  (('voting', 'state'), 10),
#  (('trump', 'job'), 10),
#  (('battle', 'trump'), 10),
#  (('immigration', 'trump'), 10),
#  (('meet', 'trump'), 10),
#  (('democratic', 'party'), 10),
#  (('trump', 'mail'), 10),
#  (('day', 'trump'), 10),
#  (('election', 'in'), 10),
#  (('republican', 'criticize'), 10),
#  (('trump', 'putin'), 10),
#  (('florida', 'united_states'), 10),
#  (('voter', 'ballot'), 10),
#  (('governor', 'voter'), 10),
#  (('sign', 'bill'), 10),
#  (('senate', 'bill'), 10),
#  (('united_states', 'senate'), 10),
#  (('russia', 'probe'), 10),
#  (('biden', 'vp'), 10),
#  (('ballot', 'voter'), 10),
#  (('trump', 'debate'), 10),
#  (('push', 'voter'), 10),
#  (('governor', 'illegal'), 10),
#  (('democrats', 'show'), 10),
#  (('law', 'people'), 10),
#  (('georgia', 'governor'), 10),
#  (('democrats', 'wear'), 10),
#  (('big', 'tech'), 10),
#  (('democrat', 'identification'), 10),
#  (('gop', 'florida'), 10),
#  (('gop', 'georgia'), 10),
#  (('border', 'migrant'), 10),
#  (('democrats', 'social'), 10),
#  (('democrats', 'call'), 10),
#  (('house', 'voting'), 10),
#  (('voting', 'people'), 10),
#  (('voting', 'media'), 10),
#  (('people', 'act'), 10),
#  (('people', 'media'), 10),
#  (('democrats', 'chinese'), 10),
#  (('democrats', 'run'), 10),
#  (('biden', 'big'), 10),
#  (('biden', 'american'), 10),
#  (('trump', 'fight'), 10),
#  (('trump', 'win'), 10),
#  (('trump', 'americans'), 10),
#  (('trump', 'reform'), 10),
#  (('biden', 'rise'), 10),
#  (('biden', 'facility'), 10),
#  (('doctor', 'coronavirus'), 10),
#  (('coronavirus', 'democratic'), 10),
#  (('biden', 'up'), 10),
#  (('coronavirus', 'expose'), 10),
#  (('coronavirus', 'owner'), 10),
#  (('coronavirus', 'uncertainty'), 10),
#  (('deal', 'coronavirus'), 10),
#  (('new_york', 'coronavirus'), 10),
#  (('one', 'coronavirus'), 10),
#  (('surgeon', 'coronavirus'), 10),
#  (('discuss', 'coronavirus'), 10),
#  (('coronavirus', 'million'), 10),
#  (('plan', 'coronavirus'), 10),
#  (('high', 'coronavirus'), 10),
#  (('million', 'coronavirus'), 10),
#  (('coronavirus', 'anthony'), 10),
#  (('dr', 'anthony'), 10),
#  (('democrats', 'block'), 10),
#  (('president', 'biden'), 10),
#  (('agenda', 'democrats'), 10),
#  (('trump', 'ballot'), 10),
#  (('governor', 'newsom'), 10),
#  (('democrats', 'student'), 10),
#  (('election', 'ballot'), 10),
#  (('vp', 'biden'), 10),
#  (('call', 'biden'), 10),
#  (('liberal', 'biden'), 10),
#  (('trump', 'china'), 10),
#  (('election', 'china'), 10),
#  (('gop', 'race'), 10),
#  (('vote', 'democrats'), 10),
#  (('voter', 'georgia'), 10),
#  (('plan', 'republican'), 10),
#  (('biden', 'spread'), 10),
#  (('coronavirus', 'move'), 10),
#  (('economic', 'biden'), 10),
#  (('law', 'bill'), 10),
#  (('biden', 'promise'), 10),
#  (('biden', 'war'), 10),
#  (('florida', 'republican'), 10),
#  (('cancel', 'culture'), 10),
#  (('reform', 'bill'), 10),
#  (('rights', 'bill'), 10),
#  (('biden', 'target'), 10),
#  (('biden', 'give'), 10),
#  (('biden', 'enter'), 10),
#  (('democracy', 'coronavirus'), 10),
#  (('georgia', 'border'), 10),
#  (('claim', 'coronavirus'), 10),
#  (('coronavirus', 'george'), 10),
#  (('democrats', 'filibuster'), 10),
#  (('democrats', 'rights'), 10),
#  (('filibuster', 'voting'), 10),
#  (('biden', 'house'), 10),
#  (('crisis', 'border'), 10),
#  (('new_york', 'times'), 10),
#  (('biden', 'charge'), 10),
#  (('governor', 'abbott'), 10),
#  (('push', 'border'), 10),
#  (('charge', 'biden'), 10),
#  (('blame', 'biden'), 10),
#  (('secretary', 'biden'), 10),
#  (('senator', 'united_states'), 10),
#  (('school', 'biden'), 10),
#  (('criticize', 'biden'), 10),
#  (('biden', 'react'), 10),
#  (('biden', 'press'), 10),
#  (('biden', 'mayor'), 10),
#  (('policy', 'democrats'), 10),
#  (('block', 'biden'), 10),
#  (('biden', 'general'), 10),
#  (('biden', 'recent'), 10),
#  (('biden', 'chinese'), 10),
#  (('voting', 'georgia'), 10),
#  (('biden', 'family'), 10),
#  (('move', 'all'), 10),
#  (('move', 'star'), 10),
#  (('move', 'game'), 10),
#  (('coronavirus', 'voting'), 10),
#  (('mask', 'biden'), 10),
#  (('mandate', 'coronavirus'), 10),
#  (('mandate', 'border'), 10),
#  (('mandate', 'vaccine'), 10),
#  (('mlb', 'move'), 10),
#  (('star', 'atlanta'), 10),
#  (('game', 'atlanta'), 10),
#  (('florida', 'police'), 10),
#  (('governor', 'police'), 10),
#  (('new_york', 'city'), 10),
#  (('biden', 'building'), 10),
#  (('biden', 'high'), 10),
#  (('biden', 'joint'), 10),
#  (('liz', 'cheney'), 10),
#  (('gop', 'coronavirus'), 10),
#  (('biden', 'chicago'), 10),
#  (('biden', 'special'), 10),
#  (('biden', 'federal'), 10),
#  (('biden', 'economy'), 10),
#  (('rights', 'coronavirus'), 10),
#  (('year', 'democrats'), 10),
#  (('vaccine', 'mandate'), 10),
#  (('biden', 'january'), 10),
#  (('biden', 'approval'), 10),
#  (('one', 'governor'), 10),
#  (('governor', 'plan'), 10),
#  (('one', 'florida'), 10),
#  (('disney', 'florida'), 10),
#  (('question', 'election'), 9),
#  (('democrats', 'day'), 9),
#  (('democrats', 'house'), 9),
#  (('voter', 'midterm'), 9),
#  (('voter', 'state'), 9),
#  (('gop', 'senator'), 9),
#  (('texas', 'border'), 9),
#  (('election', 'discuss'), 9),
#  (('law', 'voter'), 9),
#  (('law', 'texas'), 9),
#  (('united_states', 'democrat'), 9),
#  (('midterm', 'gop'), 9),
#  (('midterm', 'voter'), 9),
#  (('call', 'voter'), 9),
#  (('gop', 'candidate'), 9),
#  (('supreme_court', 'identification'), 9),
#  (('undermine', 'election'), 9),
#  (('senate', 'voter'), 9),
#  (('back', 'bill'), 9),
#  (('trump', 'poll'), 9),
#  (('trump', 'talk'), 9),
#  (('clinton', 'trump'), 9),
#  (('governor', 'people'), 9),
#  (('back', 'trump'), 9),
#  (('united_states', 'governor'), 9),
#  (('judge', 'law'), 9),
#  (('challenge', 'election'), 9),
#  (('republican', 'identification'), 9),
#  (('appeal', 'law'), 9),
#  (('republican', 'law'), 9),
#  (('voting', 'push'), 9),
#  (('voter', 'race'), 9),
#  (('trump', 'back'), 9),
#  (('voting', 'election'), 9),
#  (('republican', 'win'), 9),
#  (('police', 'trump'), 9),
#  (('information', 'trump'), 9),
#  (('united_states', 'government'), 9),
#  (('trump', 'message'), 9),
#  (('early', 'vote'), 9),
#  (('trump', 'speech'), 9),
#  (('democratic', 'election'), 9),
#  (('election', 'people'), 9),
#  (('election', 'candidate'), 9),
#  (('comey', 'clinton'), 9),
#  (('fbi', 'trump'), 9),
#  (('trump', 'congress'), 9),
#  (('media', 'united_states'), 9),
#  (('push', 'trump'), 9),
#  (('push', 'white_house'), 9),
#  (('ballot', 'fraud'), 9),
#  (('debate', 'trump'), 9),
#  (('call', 'trump'), 9),
#  (('james', 'trump'), 9),
#  (('trump', 'michael'), 9),
#  (('democrat', 'russia'), 9),
#  (('criticize', 'bill'), 9),
#  (('democrat', 'democrats'), 9),
#  (('stacey_abram', 'georgia'), 9),
#  (('stacey_abram', 'voter'), 9),
#  ...]

# %%
#RIGHT
# we filter the number of edges based on weight (aka the frequency of co-occurrence) 
filtered_r = {k: v for k, v in edgelist_right.items() if v > 3}

#LEFT
filtered_l = {k: v for k, v in edgelist_left.items() if v > 2}

# Print lengths
print("Length of filtered_l:", len(filtered_l))
print("Length of filtered_r:", len(filtered_r))
# Out:
# Length of filtered_l: 2013
# Length of filtered_r: 7021

# %%
# we create a dataframe from the edgelist dictionary wXXith a weight column denoting the number of co=occurrences of a speciic pairing
edges_right = pd.DataFrame.from_dict({'Weight': list(filtered_r.values()), 'Edge': list(filtered_r.keys())})
edges_right.head(20)
# Out:
#     Weight                        Edge
# 0        4              (radical, run)
# 1        4            (house, senator)
# 2        8            (senator, scott)
# 3       31              (texas, voter)
# 4       27     (texas, identification)
# 5       23                (texas, law)
# 6      235     (voter, identification)
# 7      103                (voter, law)
# 8        4           (voter, decision)
# 9      111       (identification, law)
# 10       4  (identification, decision)
# 11       4             (law, decision)
# 12       9        (question, election)
# 13      12             (law, election)
# 14       4                (law, fight)
# 15       7           (election, fight)
# 16       6              (year, attack)
# 17       4                (race, year)
# 18       4         (america, american)
# 19       6           (america, attack)

# %%
# we create a dataframe from the edgelist dictionary wXXith a weight column denoting the number of co=occurrences of a speciic pairing
edges_left = pd.DataFrame.from_dict({'Weight': list(filtered_l.values()), 'Edge': list(filtered_l.keys())})
edges_left.head(20)
# Out:
#     Weight                           Edge
# 0        3               (challenge, gop)
# 1        5                  (year, march)
# 2        7                 (year, voting)
# 3        7                 (year, rights)
# 4        7                (march, voting)
# 5        8                (march, rights)
# 6      206               (voting, rights)
# 7        3              (virginia, photo)
# 8        4     (virginia, identification)
# 9        3               (lawmaker, pass)
# 10       3              (lawmaker, voter)
# 11       4         (pass, identification)
# 12       4                  (pass, voter)
# 13      12        (photo, identification)
# 14       3                 (photo, voter)
# 15       8  (identification, requirement)
# 16      19        (identification, voter)
# 17       6              (vote, democrats)
# 18       7           (supreme_court, vra)
# 19       8          (supreme_court, case)

# %%
# we extract the words from the column edge so that we have a source and target word
weight_r = edges_right['Weight']
source_r = [x[0] for x in edges_right['Edge']]
target_r = [x[1] for x in edges_right['Edge']]

weight_r = weight_r.to_list()

# we create a dataframe of edges
df_edges_r = {
    'col1': source_r,
    'col2': target_r,
    'col3': weight_r,
}

df_edges_r = pd.DataFrame(df_edges_r)
df_edges_r.rename(columns={'col1': 'Source', 'col2': 'Target', 'col3':'Weight'}, inplace=True)

df_edges_r = df_edges_r.assign(Type='Undirected')

# %%
# we extract the words from the column edge so that we have a source and target word
weight_l = edges_left['Weight']
source_l = [x[0] for x in edges_left['Edge']]
target_l = [x[1] for x in edges_left['Edge']]

weight_l = weight_l.to_list()

# we create a dataframe of edges
df_edges_l = {
    'col1': source_l,
    'col2': target_l,
    'col3': weight_l,
}

df_edges_l = pd.DataFrame(df_edges_l)
df_edges_l.rename(columns={'col1': 'Source', 'col2': 'Target', 'col3':'Weight'}, inplace=True)

df_edges_l

df_edges_l = df_edges_l.assign(Type='Undirected')
df_edges_l
# Out:
#          Source   Target  Weight        Type
# 0     challenge      gop       3  Undirected
# 1          year    march       5  Undirected
# 2          year   voting       7  Undirected
# 3          year   rights       7  Undirected
# 4         march   voting       7  Undirected
# ...         ...      ...     ...         ...
# 2008      court    power       3  Undirected
# 2009      weigh     rule       4  Undirected
# 2010      power     rule       4  Undirected
# 2011      power     case       3  Undirected
# 2012   election  federal       3  Undirected
#
# [2013 rows x 4 columns]

# %% [markdown]
# #### Add word count as node attribute

# %%
words_right = right['title'].str.split().explode()
word_counts_r = words_right.value_counts().reset_index() # Calculate the word counts
word_counts_r.columns = ['word', 'count'] # Rename the columns
word_counts_r
# Out:
#                 word  count
# 0              biden    389
# 1              voter    376
# 2           election    337
# 3     identification    289
# 4              trump    260
# ...              ...    ...
# 4860         agitate      1
# 4861        uagitate      1
# 4862            type      1
# 4863         gradual      1
# 4864       monologue      1
#
# [4865 rows x 2 columns]

# %%
words_left = left['title'].str.split().explode()
word_counts_l = words_left.value_counts().reset_index() # Calculate the word counts
word_counts_l.columns = ['Id', 'count'] # Rename the columns
word_counts_l
# Out:
#                   Id  count
# 0              voter    548
# 1             voting    430
# 2                law    333
# 3               vote    283
# 4     identification    279
# ...              ...    ...
# 3414          purple      1
# 3415       tampering      1
# 3416        ugreater      1
# 3417    exclusionist      1
# 3418       disparity      1
#
# [3419 rows x 2 columns]

# %%
filtered_word_counts_l = word_counts_l[word_counts_l['Id'].isin(df_edges_l['Source']) | word_counts_l['Id'].isin(df_edges_l['Target'])]
len(filtered_word_counts_l)
# Out:
# 534

# %%
words_right = right['title'].str.split().explode()
word_counts_r = words_right.value_counts().reset_index() # Calculate the word counts
word_counts_r.columns = ['Id', 'count'] # Rename the columns
word_counts_r
# Out:
#                   Id  count
# 0              biden    389
# 1              voter    376
# 2           election    337
# 3     identification    289
# 4              trump    260
# ...              ...    ...
# 4860         agitate      1
# 4861        uagitate      1
# 4862            type      1
# 4863         gradual      1
# 4864       monologue      1
#
# [4865 rows x 2 columns]

# %%
filtered_word_counts_r = word_counts_r[word_counts_r['Id'].isin(df_edges_r['Source']) | word_counts_r['Id'].isin(df_edges_r['Target'])]
len(filtered_word_counts_r)
# Out:
# 1342

# %% [markdown]
# ## Shifterator values

# %%
nodes_df
# Out:
#          score          word left_right  norm_score
# 0     0.000049       scratch      right   -0.239889
# 1     0.000049      diagnose      right   -0.239889
# 2    -0.000018        resist       left    0.090298
# 3    -0.000068   reconfigure       left    0.330187
# 4    -0.000018          darn       left    0.090298
# ...        ...           ...        ...         ...
# 6254  0.000245       chicago      right   -1.199446
# 6255  0.000147        harass      right   -0.719668
# 6256 -0.000068     tampering       left    0.330187
# 6257 -0.000068        taunts       left    0.330187
# 6258  0.000098  unemployment      right   -0.479778
#
# [6259 rows x 4 columns]

# %%
nodes_df['score'] = abs(nodes_df['norm_score']) # convert shifterator scores all positive
nodes_df
# Out:
#          score          word left_right  norm_score
# 0     0.239889       scratch      right   -0.239889
# 1     0.239889      diagnose      right   -0.239889
# 2     0.090298        resist       left    0.090298
# 3     0.330187   reconfigure       left    0.330187
# 4     0.090298          darn       left    0.090298
# ...        ...           ...        ...         ...
# 6254  1.199446       chicago      right   -1.199446
# 6255  0.719668        harass      right   -0.719668
# 6256  0.330187     tampering       left    0.330187
# 6257  0.330187        taunts       left    0.330187
# 6258  0.479778  unemployment      right   -0.479778
#
# [6259 rows x 4 columns]

# %%
# we first remove words from the nodes list that do not appear in the edges list
nodes_df_l = nodes_df[nodes_df['word'].isin(df_edges_l['Source']) | nodes_df['word'].isin(df_edges_l['Target'])]
nodes_df_r = nodes_df[nodes_df['word'].isin(df_edges_r['Source']) | nodes_df['word'].isin(df_edges_r['Target'])]
# we then remove words from the edges list that do not appear in the nodes list
Edges_df_filtered_l = df_edges_l[df_edges_l['Source'].isin(nodes_df['word'])| df_edges_l['Target'].isin(nodes_df['word'])]
Edges_df_filtered_r = df_edges_r[df_edges_r['Source'].isin(nodes_df['word'])| df_edges_r['Target'].isin(nodes_df['word'])]
Edges_df_filtered_l
# Out:
#          Source   Target  Weight        Type
# 0     challenge      gop       3  Undirected
# 1          year    march       5  Undirected
# 2          year   voting       7  Undirected
# 3          year   rights       7  Undirected
# 4         march   voting       7  Undirected
# ...         ...      ...     ...         ...
# 2008      court    power       3  Undirected
# 2009      weigh     rule       4  Undirected
# 2010      power     rule       4  Undirected
# 2011      power     case       3  Undirected
# 2012   election  federal       3  Undirected
#
# [2013 rows x 4 columns]

# %%
# Group the DataFrame by 'Source' and 'Target' and sum the 'Weight'
df_edges_l.groupby(['Source', 'Target']).agg({'Weight': 'sum'}).reset_index()
df_edges_r.groupby(['Source', 'Target']).agg({'Weight': 'sum'}).reset_index()

# The DataFrame now has a single row for each combination of 'Source' and 'Target' with the 'Weight' values summed
df_edges_l
df_edges_r
# Out:
#        Source          Target  Weight        Type
# 0     radical             run       4  Undirected
# 1       house         senator       4  Undirected
# 2     senator           scott       8  Undirected
# 3       texas           voter      31  Undirected
# 4       texas  identification      27  Undirected
# ...       ...             ...     ...         ...
# 7016   border          tiktok       4  Undirected
# 7017   border        youngkin       4  Undirected
# 7018   border             one       4  Undirected
# 7019   tiktok        youngkin       4  Undirected
# 7020   tiktok             one       4  Undirected
#
# [7021 rows x 4 columns]

# %%
#nodes_df_filtered['Id'] = range(1, len(nodes_df_filtered) + 1) # create new ID column
nodes_df_l.rename(columns={'word': 'Id'}, inplace=True)
nodes_df_r.rename(columns={'word': 'Id'}, inplace=True)
nodes_df_r
# Out:
# C:\Users\2146806A\AppData\Local\Temp\ipykernel_22320\680586395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nodes_df_l.rename(columns={'word': 'Id'}, inplace=True)
# C:\Users\2146806A\AppData\Local\Temp\ipykernel_22320\680586395.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nodes_df_r.rename(columns={'word': 'Id'}, inplace=True)
#           score             Id left_right  norm_score
# 9      0.719668           pour      right   -0.719668
# 21    13.642681         crisis      right  -13.642681
# 22     4.834227        session       left    4.834227
# 24     0.358475  gubernatorial      right   -0.358475
# 45     0.118585      universal      right   -0.118585
# ...         ...            ...        ...         ...
# 6234   0.719668        oakland      right   -0.719668
# 6240   0.301900         review       left    0.301900
# 6246   2.644218            set       left    2.644218
# 6254   1.199446        chicago      right   -1.199446
# 6255   0.719668         harass      right   -0.719668
#
# [1340 rows x 4 columns]

# %% [markdown]
# Add counts as attributes

# %%
words_r = right['title'].str.split().explode()
words_l = left['title'].str.split().explode()

# Calculate the word counts
word_counts_r = words_r.value_counts().reset_index()
word_counts_l = words_l.value_counts().reset_index()

# Rename the columns
word_counts_r.columns = ['Id', 'count']
word_counts_l.columns = ['Id', 'count']

# %%
word_counts_l
# Out:
#                   Id  count
# 0              voter    548
# 1             voting    430
# 2                law    333
# 3               vote    283
# 4     identification    279
# ...              ...    ...
# 3414          purple      1
# 3415       tampering      1
# 3416        ugreater      1
# 3417    exclusionist      1
# 3418       disparity      1
#
# [3419 rows x 2 columns]

# %%
# Get unique words from 'source' and 'target' columns in the edgelist dataframe
unique_words_l = set(df_edges_l['Source']).union(set(df_edges_l['Target']))
unique_words_r = set(df_edges_r['Source']).union(set(df_edges_r['Target']))

# Filter the word counts dataframe based on unique words
filtered_word_counts_l = word_counts_l[word_counts_l['Id'].isin(unique_words_l)]
filtered_word_counts_r = word_counts_r[word_counts_r['Id'].isin(unique_words_r)]

# %%
nodes_df_l
# Out:
#           score             Id left_right  norm_score
# 21    13.642681         crisis      right  -13.642681
# 22     4.834227        session       left    4.834227
# 28     1.080861           norm       left    1.080861
# 48    22.463622  supreme_court       left   22.463622
# 54     1.650937         stress       left    1.650937
# ...         ...            ...        ...         ...
# 6214   4.173852             it       left    4.173852
# 6222   1.163004           real      right   -1.163004
# 6224   1.047137        attempt      right   -1.047137
# 6240   0.301900         review       left    0.301900
# 6246   2.644218            set       left    2.644218
#
# [533 rows x 4 columns]

# %%
nodes_df_filtered_l = nodes_df_l[nodes_df_l['Id'].isin(unique_words_l)]
nodes_df_filtered_r = nodes_df_r[nodes_df_r['Id'].isin(unique_words_r)]

# %%
nodes_df_filtered_r = pd.merge(nodes_df_filtered_r, filtered_word_counts_r, on='Id', how='left')
nodes_df_filtered_l = pd.merge(nodes_df_filtered_l, filtered_word_counts_l, on='Id', how='left')
nodes_df_filtered_r
# Out:
#           score             Id left_right  norm_score  count
# 0      0.719668           pour      right   -0.719668      3
# 1     13.642681         crisis      right  -13.642681     61
# 2      4.834227        session       left    4.834227      6
# 3      0.358475  gubernatorial      right   -0.358475      7
# 4      0.118585      universal      right   -0.118585      6
# ...         ...            ...        ...         ...    ...
# 1335   0.719668        oakland      right   -0.719668      3
# 1336   0.301900         review       left    0.301900      7
# 1337   2.644218            set       left    2.644218     11
# 1338   1.199446        chicago      right   -1.199446      5
# 1339   0.719668         harass      right   -0.719668      3
#
# [1340 rows x 5 columns]

# %%
nodes_df_filtered_l
# Out:
#          score             Id left_right  norm_score  count
# 0    13.642681         crisis      right  -13.642681      3
# 1     4.834227        session       left    4.834227     19
# 2     1.080861           norm       left    1.080861      4
# 3    22.463622  supreme_court       left   22.463622    100
# 4     1.650937         stress       left    1.650937      5
# ..         ...            ...        ...         ...    ...
# 528   4.173852             it       left    4.173852     17
# 529   1.163004           real      right   -1.163004     19
# 530   1.047137        attempt      right   -1.047137      7
# 531   0.301900         review       left    0.301900      6
# 532   2.644218            set       left    2.644218     16
#
# [533 rows x 5 columns]

# %%
nodes_df_filtered_l['count'].isna().sum()
# Out:
# 0

# %%
nodes_df_filtered_l = nodes_df_filtered_l.drop('norm_score', axis=1)
nodes_df_filtered_r = nodes_df_filtered_r.drop('norm_score', axis=1)

# %%
nodes_df_filtered_r = nodes_df_filtered_r.dropna(subset=['count'])
nodes_df_filtered_r.head()
# Out:
#        score             Id left_right  count
# 0   0.719668           pour      right      3
# 1  13.642681         crisis      right     61
# 2   4.834227        session       left      6
# 3   0.358475  gubernatorial      right      7
# 4   0.118585      universal      right      6

# %%
nodes_df_filtered_l = nodes_df_filtered_l.dropna(subset=['count'])
nodes_df_filtered_l.head()
# Out:
#        score             Id left_right  count
# 0  13.642681         crisis      right      3
# 1   4.834227        session       left     19
# 2   1.080861           norm       left      4
# 3  22.463622  supreme_court       left    100
# 4   1.650937         stress       left      5

# %%
len(nodes_df_filtered_l)
# Out:
# 533

# %%
nodes_df_filtered_l
# Out:
#          score             Id left_right  count
# 0    13.642681         crisis      right      3
# 1     4.834227        session       left     19
# 2     1.080861           norm       left      4
# 3    22.463622  supreme_court       left    100
# 4     1.650937         stress       left      5
# ..         ...            ...        ...    ...
# 528   4.173852             it       left     17
# 529   1.163004           real      right     19
# 530   1.047137        attempt      right      7
# 531   0.301900         review       left      6
# 532   2.644218            set       left     16
#
# [533 rows x 4 columns]

# %%
nodes_df_filtered_l = nodes_df_filtered_l[['Id', 'score', 'left_right', 'count']]

# %%
Edges_df_filtered_l
# Out:
#          Source   Target  Weight        Type
# 0     challenge      gop       3  Undirected
# 1          year    march       5  Undirected
# 2          year   voting       7  Undirected
# 3          year   rights       7  Undirected
# 4         march   voting       7  Undirected
# ...         ...      ...     ...         ...
# 2008      court    power       3  Undirected
# 2009      weigh     rule       4  Undirected
# 2010      power     rule       4  Undirected
# 2011      power     case       3  Undirected
# 2012   election  federal       3  Undirected
#
# [2013 rows x 4 columns]

# %%
#save edgelist as csv file to import into Gephi
df_edges_l.to_csv('C:/Users/2146806A/OneDrive - University of Glasgow/University of Glasgow/Amsterdam Visit/GITHUB FILES/Data/edges_left_title_nov23.csv', index=False)
df_edges_r.to_csv('C:/Users/2146806A/OneDrive - University of Glasgow/University of Glasgow/Amsterdam Visit/GITHUB FILES/Data/edges_right_title_nov23.csv', index=False)

# %%
nodes_df_filtered_l.to_csv('C:/Users/2146806A/OneDrive - University of Glasgow/University of Glasgow/Amsterdam Visit/GITHUB FILES/Data/nodes_left_title_nov23.csv', index=False) #export to csv
nodes_df_filtered_r.to_csv('C:/Users/2146806A/OneDrive - University of Glasgow/University of Glasgow/Amsterdam Visit/GITHUB FILES/Data/nodes_right_title_nov23.csv', index=False) #export to csv

# %%
# FOR MAIN BODY OF TEXT
# Split corpus into right and left news media
left = df[df['ideology'].isin(['left'])]
right = df[df['ideology'].isin(['right'])]

# we want to find co-occurrences of words in sentences so we convert the text_sentence column into a list
right_list = right['maintext'].tolist()
left_list = left['maintext'].tolist()

# %%
# split the articles into sentences and create a dataframe with the sentences
sentences_left = []
for article in left_list:
    if isinstance(article, str) and article.strip():
        article_sentences = sent_tokenize(article)
        sentences_left.extend(article_sentences)

df_sentences_left= pd.DataFrame({'sentences': sentences_left})

sentences_right = []
for article in right_list:
    if isinstance(article, str) and article.strip():
        article_sentences = sent_tokenize(article)
        sentences_right.extend(article_sentences)

df_sentences_right= pd.DataFrame({'sentences': sentences_right})

# we create a list of individual sentences
sentences_left = df_sentences_left['sentences'].tolist()
sentences_right = df_sentences_right['sentences'].tolist()

# %%
# MEMORY ERROR HERE
# edgelist dictionary for right
edgelist_right = defaultdict(int)
for text in tokenized_right:
    for node1, node2 in combinations(text, 2):
        if node1 != node2:  # Skip pairs with the same node
            edgelist_right[(node1, node2)] += 1

# left
edgelist_left = defaultdict(int)
for text in tokenized_left:
    for node1, node2 in combinations(text, 2):
        if node1 != node2:  # Skip pairs with the same node
            edgelist_left[(node1, node2)] += 1
# Out:
# ---------------------------------------------------------------------------
#
# MemoryError                               Traceback (most recent call last)
#
# c:\Users\2146806A\OneDrive - University of Glasgow\University of Glasgow\Amsterdam Visit\GITHUB FILES\Scripts\networks_fileprep_maintext.ipynb Cell 15 in 6
#
#       <a href='vscode-notebook-cell:/c%3A/Users/2146806A/OneDrive%20-%20University%20of%20Glasgow/University%20of%20Glasgow/Amsterdam%20Visit/GITHUB%20FILES/Scripts/networks_fileprep_maintext.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a>     for node1, node2 in combinations(text, 2):
#
#       <a href='vscode-notebook-cell:/c%3A/Users/2146806A/OneDrive%20-%20University%20of%20Glasgow/University%20of%20Glasgow/Amsterdam%20Visit/GITHUB%20FILES/Scripts/networks_fileprep_maintext.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a>         if node1 != node2:  # Skip pairs with the same node
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/2146806A/OneDrive%20-%20University%20of%20Glasgow/University%20of%20Glasgow/Amsterdam%20Visit/GITHUB%20FILES/Scripts/networks_fileprep_maintext.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a>             edgelist_right[(node1, node2)] += 1
#
#       <a href='vscode-notebook-cell:/c%3A/Users/2146806A/OneDrive%20-%20University%20of%20Glasgow/University%20of%20Glasgow/Amsterdam%20Visit/GITHUB%20FILES/Scripts/networks_fileprep_maintext.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a> # left
#
#       <a href='vscode-notebook-cell:/c%3A/Users/2146806A/OneDrive%20-%20University%20of%20Glasgow/University%20of%20Glasgow/Amsterdam%20Visit/GITHUB%20FILES/Scripts/networks_fileprep_maintext.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a> edgelist_left = defaultdict(int)
#
#
#
# MemoryError:
